# %% [markdown]
# # 1. 구글 드라이브 마운트

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 2. PhysioNet 로그인 & 다운로드 (wget 사용)

# %%
# !wget -r -N -c -np \
     --user hyeongjun --ask-password \
     https://physionet.org/files/mimiciv/3.1/ \
     -P /content/drive/MyDrive/DILAB/mimiciv_3.1
# Out:
# Password for user ‘hyeongjun’:
# --2025-09-11 01:49:28--  https://physionet.org/files/mimiciv/3.1/
# Resolving physionet.org (physionet.org)... 18.18.42.54
# Connecting to physionet.org (physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="PhysioNet", charset="UTF-8"
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/content/drive/MyDrive/DILAB/mimiciv_3.1/physionet.org/files/mimiciv/3.1/index.html’
#
# physionet.org/files     [ <=>                ]     789  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-09-11 01:49:29 (125 MB/s) - ‘/content/drive/MyDrive/DILAB/mimiciv_3.1/physionet.org/files/mimiciv/3.1/index.html’ saved [789]
#
# Loading robots.txt; please ignore errors.
# --2025-09-11 01:49:29--  https://physionet.org/robots.txt
# ...
