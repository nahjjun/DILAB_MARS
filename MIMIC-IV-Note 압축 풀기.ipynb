# %% [markdown]
# # 1. 구글 드라이브 마운트

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 2. 병렬 압축해제 도구 설치

# %%
# !apt -y install pigz
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# pigz is already the newest version (2.6-1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.

# %% [markdown]
# # 3. 작업 폴더로 이동 후 병렬로 모두 해제

# %%
# %cd /content/drive/MyDrive/DILAB/MARS/mimic-iv-note_2.2
# !find . -type f -name "*.gz" -print0 | xargs -0 -n1 -P 8 pigz -d -k
# Out:
# /content/drive/MyDrive/DILAB/mimic-iv-note_2.2
